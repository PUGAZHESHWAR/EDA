# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.random(100)*100
y = np.random.random(100)*100

# %%
plt.scatter(x,y,c='#000',marker="*",s=200,alpha=0.3)
plt.show()

# %%
years = [2006 + x for x in range(16)]
weights = np.random.randint(75,90,(16))

# %%
print(years,
weights)
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021] [79 87 79 85 87 87 78 83 81 77 85 88 78 89 77 78]

# %%
plt.scatter(years,weights)

# %%
plt.plot(years,weights,c='blue',lw=4,linestyle='--')

# %%
plt.plot(years,weights,"r--",lw=2)
